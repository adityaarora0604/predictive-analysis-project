# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


df=pd.read_csv("cleaned_data.csv")
df.head()
# Out:
#    Fiscal Year  Library  County  AENGLC Rank  Population of Service Area  \
# 0         1996        0       6        109.0                      2815.0
# 1         1996        1       4        158.0                     17825.0
# 2         1996        3       7        131.0                      3969.0
# 3         1996        4       1         19.0                     14143.0
# 4         1996        5       4        129.0                      5351.0
#
#    Total Library Visits  Library Visits Per Capita Served  \
# 0               15000.0                               5.3
# 1               91756.0                               5.1
# 2                8665.0                               2.2
# 3              162893.0                              11.5
# 4                7000.0                               1.3
#
#    Total Registered Borrowers  Percent of Residents with Library Cards  \
# 0                      1313.0                                     0.47
# 1                      6952.0                                     0.39
# 2                      1360.0                                     0.34
# 3                      8808.0                                     0.62
# 4                      1379.0                                     0.26
#
#    Reference Questions  ...  Total Collection  Collection Per Capita Served  \
# 0                499.0  ...           15285.0                           5.4
# 1               5771.5  ...           63685.0                           3.6
# 2                207.0  ...           23818.0                           6.0
# 3              15283.0  ...           74903.0                           5.3
# 4                400.0  ...           10042.0                           1.9
#
#    Total Operating Income  Operating Income Per Capita  \
# 0                 56300.0                        20.00
# 1                320679.0                        17.99
# 2                111699.0                        28.14
# 3                685678.0                        48.48
# 4                 40806.0                         7.63
#
#    Town Tax Appropriation for Library  Tax Appropriation Per Capita Served  \
# 0                             52915.0                                18.80
# 1                            323503.0                                18.15
# 2                            106713.0                                26.89
# 3                            602831.0                                42.62
# 4                             39256.0                                 7.34
#
#    Library Materials Expenditures  Wages & Salaries Expenditures  \
# 0                         10073.0                        30996.0
# 1                         45874.0                       201621.0
# 2                         11508.0                        62295.0
# 3                         92711.0                       340400.0
# 4                          4298.0                        21585.0
#
#    Operating Expenditures  Operating Expenditures Per Capita
# 0                 44290.0                               15.7
# 1                270658.0                               15.2
# 2                 82769.0                               20.9
# 3                516583.0                               36.5
# 4                 39165.0                                7.3
#
# [5 rows x 26 columns]

# %%
num_cols = df.select_dtypes(include=['int64','float64']).columns

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(), cmap='coolwarm', annot=False)
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.scatterplot(x='Total Operating Income', y='Total Circulation', data=df)
plt.title("Total Operating Income vs Total Circulation")
plt.show()

# %%
sns.scatterplot(x='Population of Service Area', y='Total Circulation', data=df, color="red" )
plt.title("Population vs Total Circulation")
plt.show()

# %%
heatmap_fig=plt.figure(figsize=(8,6))
sns.heatmap(df.corr(), cmap='coolwarm', annot=False)
heatmap_fig.savefig("visuals/correlation_heatmap.png")

# %%
important_cols = [
    'Population of Service Area',
    'Total Library Visits',
    'Total Circulation',
    'Total Operating Income',
    'Operating Expenditures',
    'Town Tax Appropriation for Library',
    'Library Materials Expenditures'
]

plt.figure(figsize=(10,7))
sns.heatmap(df[important_cols].corr(), annot=True, cmap='coolwarm')
plt.title("Focused Correlation Heatmap")
plt.show()

# %%
df.groupby('County')['Total Circulation'].sum().sort_values(ascending=False).head(10).plot(
    kind='bar', figsize=(10,5)
)
plt.title("Top 10 Counties by Total Circulation")
plt.ylabel("Total Circulation")
plt.show()

# %%
df.corr()['Total Circulation'].sort_values(ascending=False).head(10)
# Out:
# Total Circulation                     1.000000
# Total Library Visits                  0.882252
# Library Materials Expenditures        0.872400
# Wages & Salaries Expenditures         0.801396
# Town Tax Appropriation for Library    0.785562
# Total Collection                      0.770796
# Operating Expenditures                0.767144
# Total Operating Income                0.765143
# Total Registered Borrowers            0.721271
# Reference Questions                   0.704303
# Name: Total Circulation, dtype: float64

# %%
df.corr()['Total Operating Income'].sort_values(ascending=False).head(10)
# Out:
# Total Operating Income                1.000000
# Operating Expenditures                0.985164
# Town Tax Appropriation for Library    0.984381
# Wages & Salaries Expenditures         0.977088
# Library Materials Expenditures        0.880693
# Total Collection                      0.820193
# Total Library Visits                  0.798025
# Total Program Attendance & Views      0.794420
# Population of Service Area            0.778169
# Total Circulation                     0.765143
# Name: Total Operating Income, dtype: float64
